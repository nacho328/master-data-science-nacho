# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

plt.style.use ('ggplot')

# %matplotlib inline

# %% [markdown]
# # Loading CSV

# %%
# !ls /home/dsc/Data/us_dot/traffic
# Out:
# T100_SEGMENT_ALL_CARRIER_2014.zip  T100_SEGMENT_ALL_CARRIER_2015.zip

# %%
# !ls /home/dani/repos/master-data-science/data/us_dot/traffic/
# Out:
# ls: cannot access '/home/dani/repos/master-data-science/data/us_dot/traffic/': No such file or directory

# %%
# !unzip -o /home/dsc/Data/us_dot/traffic/T100_SEGMENT_ALL_CARRIER_2015.zip # -o sobreescribe
# Out:
# Archive:  /home/dsc/Data/us_dot/traffic/T100_SEGMENT_ALL_CARRIER_2015.zip
#   inflating: 914310910_T_T100_SEGMENT_ALL_CARRIER_2015_All.csv
#   inflating: 914310910_T_T100_SEGMENT_ALL_CARRIER_ReadMe.csv
#   inflating: 914310910_T_T100_SEGMENT_ALL_CARRIER_Terms.csv

# %%
filename = '914310910_T_T100_SEGMENT_ALL_CARRIER_2015_All.csv'

df = pd.read_csv(filename)    # Lee un fichero cdv. El seperado por defecto es ",". Si va "NY, USA" no es separador
df.head()                     # Si no tiene indice lo genera, aunque es mejor crear uno
# Out:
#    DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED  PAYLOAD  SEATS  PASSENGERS  \
# 0                   0.0                   1.0    528.0   11.0         2.0
# 1                   0.0                   2.0   3621.0   22.0         2.0
# 2                   0.0                   1.0   2169.0   11.0         2.0
# 3                   0.0                   1.0   1342.0   11.0         1.0
# 4                   0.0                   1.0    275.0   11.0         1.0
#
#    FREIGHT  MAIL  DISTANCE  RAMP_TO_RAMP  AIR_TIME UNIQUE_CARRIER  AIRLINE_ID  \
# 0      0.0   0.0    3899.0           0.0       0.0            10Q     21407.0
# 1      0.0   0.0    2589.0           0.0       0.0            10Q     21407.0
# 2      0.0   0.0    1210.0           0.0       0.0            10Q     21407.0
# 3      0.0   0.0    2316.0           0.0       0.0            10Q     21407.0
# 4      0.0   0.0    1023.0           0.0       0.0            10Q     21407.0
#
# ...

# %% [markdown]
# Hay muchos argumentos con pd.read_csv(file): skiprows para eliminar celdas vacias o quoterchar para delimitar.
# Si son muchos registros hace ellipsis, mosrtrando solo los primeros y los ultimos.

# %%
df.sample(5)     # muestra 5 de ejemplo
# Out:
#         DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED    PAYLOAD   SEATS  \
# 6351                     0.0                   1.0    57000.0     0.0
# 113177                  29.0                  46.0   206182.0   871.0
# 75604                    4.0                   4.0   118200.0   512.0
# 29204                    0.0                   2.0    85000.0   346.0
# 133477                  61.0                  58.0  2341000.0  9270.0
#
#         PASSENGERS  FREIGHT    MAIL  DISTANCE  RAMP_TO_RAMP  AIR_TIME  \
# 6351           0.0  33840.0     0.0    1212.0         156.0     138.0
# 113177       290.0      0.0     0.0     385.0        4579.0    3974.0
# 75604        448.0    587.0  2099.0     589.0         411.0     316.0
# 29204        328.0      0.0     0.0    2211.0         525.0     495.0
# 133477      8018.0   3021.0   798.0     247.0        3984.0    2730.0
#
#        UNIQUE_CARRIER  AIRLINE_ID       UNIQUE_CARRIER_NAME  \
# ...

# %%
pd.options.display.max_columns = None
df.head()          # muestra las primeras 5 lineas
# Out:
#    DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED  PAYLOAD  SEATS  PASSENGERS  \
# 0                   0.0                   1.0    528.0   11.0         2.0
# 1                   0.0                   2.0   3621.0   22.0         2.0
# 2                   0.0                   1.0   2169.0   11.0         2.0
# 3                   0.0                   1.0   1342.0   11.0         1.0
# 4                   0.0                   1.0    275.0   11.0         1.0
#
#    FREIGHT  MAIL  DISTANCE  RAMP_TO_RAMP  AIR_TIME UNIQUE_CARRIER  AIRLINE_ID  \
# 0      0.0   0.0    3899.0           0.0       0.0            10Q     21407.0
# 1      0.0   0.0    2589.0           0.0       0.0            10Q     21407.0
# 2      0.0   0.0    1210.0           0.0       0.0            10Q     21407.0
# 3      0.0   0.0    2316.0           0.0       0.0            10Q     21407.0
# 4      0.0   0.0    1023.0           0.0       0.0            10Q     21407.0
#
# ...

# %% [markdown]
# # Saving to Excel

# %%
df.head(1000).to_excel('excel_output.xls')

# %% [markdown]
# # Saving to CSV

# %%
df.sample(10).to_csv('sample.csv')

# %%
df.sample(3).to_csv()
# Out:
# ',DEPARTURES_SCHEDULED,DEPARTURES_PERFORMED,PAYLOAD,SEATS,PASSENGERS,FREIGHT,MAIL,DISTANCE,RAMP_TO_RAMP,AIR_TIME,UNIQUE_CARRIER,AIRLINE_ID,UNIQUE_CARRIER_NAME,UNIQUE_CARRIER_ENTITY,REGION,CARRIER,CARRIER_NAME,CARRIER_GROUP,CARRIER_GROUP_NEW,ORIGIN_AIRPORT_ID,ORIGIN_AIRPORT_SEQ_ID,ORIGIN_CITY_MARKET_ID,ORIGIN,ORIGIN_CITY_NAME,ORIGIN_STATE_ABR,ORIGIN_STATE_FIPS,ORIGIN_STATE_NM,ORIGIN_COUNTRY,ORIGIN_COUNTRY_NAME,ORIGIN_WAC,DEST_AIRPORT_ID,DEST_AIRPORT_SEQ_ID,DEST_CITY_MARKET_ID,DEST,DEST_CITY_NAME,DEST_STATE_ABR,DEST_STATE_FIPS,DEST_STATE_NM,DEST_COUNTRY,DEST_COUNTRY_NAME,DEST_WAC,AIRCRAFT_GROUP,AIRCRAFT_TYPE,AIRCRAFT_CONFIG,YEAR,QUARTER,MONTH,DISTANCE_GROUP,CLASS,DATA_SOURCE,Unnamed: 50\n14505,0.0,1.0,51360.0,180.0,177.0,0.0,0.0,54.0,53.0,22.0,DL,19790.0,Delta Air Lines Inc.,01260,D,DL,Delta Air Lines Inc.,3,3.0,13204,1320402,31454,MCO,"Orlando, FL",FL,12.0,Florida,US,United States,33,11252,1125203,31252,DAB,"Daytona Beach, FL",FL,12.0,Florida,US,United States,33,6,622,1,2015,1,2,1,F,D
# ...

# %%
s = 'a\nb'     # '\n' es un solo carácter  en linux
len(s)
# Out:
# 3

# %%
print(s)
# Out:
# a
# b

# %% [markdown]
# # To Sql Database

# %%
import sqlite3               # Es para conectar  y crear a una base de datos

conn = sqlite3.connect('example.db')      # Crea la base de datos conn

# %%
df.to_sql('traffic', conn, if_exists='replace')  # Crea la tabla traffic dentro de la base de datos conn y pasa contenido
# Out:
# /home/dsc/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:1362: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   chunksize=chunksize, dtype=dtype)

# %% [markdown]
# dbapi es una funcionalidad. Python es Database API es para conectar con cualquier base de datos con el mismo codigo

# %% [markdown]
# # Reading mysql database

# %%
df2 = pd.read_sql_query('SELECT * FROM traffic WHERE PASSENGERS > 10000',
                        conn)

df2.head()
# Out:
#    index  DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED    PAYLOAD    SEATS  \
# 0     37                   0.0                  61.0  5365411.0  18353.0
# 1     42                   0.0                  61.0  5365411.0  18353.0
# 2     56                   0.0                  28.0  3619370.0  14448.0
# 3     58                   0.0                  31.0  4054899.0  15996.0
# 4     59                   0.0                  27.0  3470887.0  13836.0
#
#    PASSENGERS    FREIGHT  MAIL  DISTANCE  RAMP_TO_RAMP  AIR_TIME  \
# 0     16933.0   571685.0   0.0    4395.0           0.0       0.0
# 1     16827.0  1274568.0   0.0    4395.0           0.0       0.0
# 2     12556.0   478166.0   0.0    3635.0           0.0       0.0
# 3     13913.0   423487.0   0.0    5670.0           0.0       0.0
# 4     12888.0   413138.0   0.0    4589.0           0.0       0.0
#
#   UNIQUE_CARRIER  AIRLINE_ID        UNIQUE_CARRIER_NAME UNIQUE_CARRIER_ENTITY  \
# ...

# %% [markdown]
# # To dictionary and to json  (Java Script Object)

# %%
df.sample(5).to_dict()  # lo pasamos a un diccionario que es la forma de leerlo desde json
# Out:
# {'AIRCRAFT_CONFIG': {14933: 1, 15581: 2, 31097: 1, 38041: 1, 146211: 1},
#  'AIRCRAFT_GROUP': {14933: 6, 15581: 6, 31097: 6, 38041: 6, 146211: 6},
#  'AIRCRAFT_TYPE': {14933: 623,
#   15581: 640,
#   31097: 617,
#   38041: 612,
#   146211: 694},
#  'AIRLINE_ID': {14933: 19790.0,
#   15581: 20447.0,
#   31097: 21142.0,
#   38041: 19534.0,
#   146211: 21171.0},
#  'AIR_TIME': {14933: 99.0,
#   15581: 174.0,
#   31097: 0.0,
#   38041: 0.0,
#   146211: 11437.0},
#  'CARRIER': {14933: 'DL', 15581: 'U7', 31097: '9V', 38041: 'AM', 146211: 'VX'},
#  'CARRIER_GROUP': {14933: 3, 15581: 2, 31097: 0, 38041: 0, 146211: 3},
#  'CARRIER_GROUP_NEW': {14933: 3.0,
#   15581: 2.0,
#   31097: 0.0,
#   38041: 0.0,
#   146211: 3.0},
#  'CARRIER_NAME': {14933: 'Delta Air Lines Inc.',
#   15581: 'USA Jet Airlines Inc.',
#   31097: 'Avior Airlines, C.A.',
#   38041: 'Aeromexico',
#   146211: 'Virgin America'},
#  'CLASS': {14933: 'F', 15581: 'P', 31097: 'F', 38041: 'F', 146211: 'F'},
# ...

# %%
df.sample(5).to_json()  # lo pasamos a formato json que es muy parecido a un diccionario
# Out:
# '{"DEPARTURES_SCHEDULED":{"74225":4.0,"30006":0.0,"126310":47.0,"76183":4.0,"11168":0.0},"DEPARTURES_PERFORMED":{"74225":4.0,"30006":31.0,"126310":47.0,"76183":0.0,"11168":4.0},"PAYLOAD":{"74225":188040.0,"30006":994594.0,"126310":470000.0,"76183":0.0,"11168":12700.0},"SEATS":{"74225":728.0,"30006":5664.0,"126310":2350.0,"76183":0.0,"11168":36.0},"PASSENGERS":{"74225":584.0,"30006":4968.0,"126310":2181.0,"76183":0.0,"11168":5.0},"FREIGHT":{"74225":0.0,"30006":0.0,"126310":0.0,"76183":0.0,"11168":0.0},"MAIL":{"74225":0.0,"30006":0.0,"126310":0.0,"76183":0.0,"11168":290.0},"DISTANCE":{"74225":3414.0,"30006":2002.0,"126310":528.0,"76183":1069.0,"11168":40.0},"RAMP_TO_RAMP":{"74225":1907.0,"30006":0.0,"126310":4483.0,"76183":0.0,"11168":76.0},"AIR_TIME":{"74225":1812.0,"30006":0.0,"126310":3397.0,"76183":0.0,"11168":60.0},"UNIQUE_CARRIER":{"74225":"UA","30006":"LJ","126310":"EV","76183":"DL","11168":"8E"},"AIRLINE_ID":{"74225":19977.0,"30006":21416.0,"126310":20366.0,"76183":19790.0,"111
# ...

# %% [markdown]
# # Reading Excel

# %%
pd.read_excel('excel_output.xls').head()
# Out:
#    DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED  PAYLOAD  SEATS  PASSENGERS  \
# 0                     0                     1      528     11           2
# 1                     0                     2     3621     22           2
# 2                     0                     1     2169     11           2
# 3                     0                     1     1342     11           1
# 4                     0                     1      275     11           1
#
#    FREIGHT  MAIL  DISTANCE  RAMP_TO_RAMP  AIR_TIME UNIQUE_CARRIER  AIRLINE_ID  \
# 0        0     0      3899             0         0            10Q       21407
# 1        0     0      2589             0         0            10Q       21407
# 2        0     0      1210             0         0            10Q       21407
# 3        0     0      2316             0         0            10Q       21407
# 4        0     0      1023             0         0            10Q       21407
#
# ...

# %%
accidentes_2009 = pd.read_excel('/home/dsc/Downloads/01_ ACCIDENTES POR TIPO EN  DISTRITOS.xls',
                                skiprows=7,skipfooter=1,parse_cols='A:K')
accidentes_2009
# skiprows (filas que se omiten al principio),skipfooter(filas que se omiten al final)
# Out:
#                 DISTRITO_ACCIDENTE  COLISIÓN DOBLE                            \
# 0   ARGANZUELA                                                           389
# 1   BARAJAS                                                               89
# 2   CARABANCHEL                                                          375
# 3   CENTRO                                                               514
# 4   CHAMARTIN                                                            494
# 5   CHAMBERI                                                             414
# 6   CIUDAD LINEAL                                                        398
# 7   FUENCARRAL-EL PARDO                                                  321
# 8   HORTALEZA                                                            215
# 9   LATINA                                                               298
# 10  MONCLOA-ARAVACA                                                      340
# ...

# %%
accidentes_2010 = pd.read_excel('/home/dsc/Downloads/01_ ACCIDENTES POR TIPO EN  DISTRITOS.xls',
                                skiprows=7,skipfooter=1,parse_cols='A:K',sheetname='2010')
accidentes_2010
# Out:
#                 DISTRITO_ACCIDENTE  COLISIÓN DOBLE                            \
# 0   ARGANZUELA                                                           403
# 1   BARAJAS                                                               62
# 2   CARABANCHEL                                                          357
# 3   CENTRO                                                               546
# 4   CHAMARTIN                                                            460
# 5   CHAMBERI                                                             361
# 6   CIUDAD LINEAL                                                        404
# 7   FUENCARRAL-EL PARDO                                                  294
# 8   HORTALEZA                                                            183
# 9   LATINA                                                               273
# 10  MONCLOA-ARAVACA                                                      350
# ...

# %% [markdown]
# #### Exercise
#
# Consolidate the excel into one DataFrame: you will need to create a 'YEAR' column. Think how you can iterate through all the DataFrames. Think also where you can take the value of 'YEAR' from.

# %%
sheets = pd.read_excel('/home/dsc/Downloads/01_ ACCIDENTES POR TIPO EN  DISTRITOS.xls',
                       skiprows=7, skipfooter=1, parse_cols='A:K', 
                       sheetname=None)

result = []

for name in sheets.keys():
    
    year = int(name)
    
    skiprows = 4 if year == 2013 else 7
    
    this_sheet = pd.read_excel('/home/dsc/Downloads/01_ ACCIDENTES POR TIPO EN  DISTRITOS.xls',
                       skiprows=skiprows, skipfooter=1, parse_cols='A:K', 
                       sheetname=name)
    
    this_sheet['YEAR'] = year
    result.append(this_sheet)
    
whole_df = pd.concat(result)

whole_df.sample(3)
# Out:
#                 DISTRITO_ACCIDENTE  COLISIÓN DOBLE                            \
# 20  VILLAVERDE                                                           140
# 11  MORATALAZ                                                            150
# 20  VILLAVERDE                                                           177
#
#     COLISIÓN MÚLTIPLE                         \
# 20                                        10
# 11                                        31
# 20                                        11
#
#     CHOQUE CON OBJETO FIJO                    \
# 20                                        75
# 11                                        53
# 20                                        71
#
#     ATROPELLO                                 \
# 20                                        46
# 11                                        32
# 20                                        54
#
#     VUELCO                                    \
# 20                                       1.0
# ...

# %%
whole_df.loc[1]
# Out:
#                DISTRITO_ACCIDENTE  COLISIÓN DOBLE                            \
# 1  BARAJAS                                                               89
# 1  BARAJAS                                                               62
# 1  BARAJAS                                                               78
# 1  BARAJAS                                                               82
# 1  BARAJAS                                                               70
# 1  BARAJAS                                                               76
# 1  BARAJAS                                                               77
# 1  BARAJAS                                                               95
#
#    COLISIÓN MÚLTIPLE                         \
# 1                                         6
# 1                                         5
# 1                                         3
# 1                                         5
# 1                                         4
# ...
