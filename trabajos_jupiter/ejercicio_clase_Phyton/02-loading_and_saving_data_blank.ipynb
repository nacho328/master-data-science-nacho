# %% [markdown]
# # Loading CSV

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use ('ggplot')

# %matplotlib inline

# %%
# !ls /home/dsc/Data/us_dot/traffic/
# Out:
# T100_SEGMENT_ALL_CARRIER_2014.zip  T100_SEGMENT_ALL_CARRIER_2015.zip

# %%
man unzip

# %%
# !unzip
# Out:
# UnZip 6.00 of 20 April 2009, by Info-ZIP.  Maintained by C. Spieler.  Send
# bug reports using http://www.info-zip.org/zip-bug.html; see README for details.
#
# Usage: unzip [-Z] [-opts[modifiers]] file[.zip] [list] [-x xlist] [-d exdir]
#   Default action is to extract files in list, except those in xlist, to exdir;
#   file[.zip] may be a wildcard.  -Z => ZipInfo mode ("unzip -Z" for usage).
#
#   -p  extract files to pipe, no messages     -l  list files (short format)
#   -f  freshen existing files, create none    -t  test compressed archive data
#   -u  update files, create if necessary      -z  display archive comment only
#   -v  list verbosely/show version info       -T  timestamp archive to latest
#   -x  exclude files that follow (in xlist)   -d  extract files into exdir
# modifiers:
#   -n  never overwrite existing files         -q  quiet mode (-qq => quieter)
#   -o  overwrite files WITHOUT prompting      -a  auto-convert any text files
# ...

# %%
# !unzip -o
# Out:
# UnZip 6.00 of 20 April 2009, by Info-ZIP.  Maintained by C. Spieler.  Send
# bug reports using http://www.info-zip.org/zip-bug.html; see README for details.
#
# Usage: unzip [-Z] [-opts[modifiers]] file[.zip] [list] [-x xlist] [-d exdir]
#   Default action is to extract files in list, except those in xlist, to exdir;
#   file[.zip] may be a wildcard.  -Z => ZipInfo mode ("unzip -Z" for usage).
#
#   -p  extract files to pipe, no messages     -l  list files (short format)
#   -f  freshen existing files, create none    -t  test compressed archive data
#   -u  update files, create if necessary      -z  display archive comment only
#   -v  list verbosely/show version info       -T  timestamp archive to latest
#   -x  exclude files that follow (in xlist)   -d  extract files into exdir
# modifiers:
#   -n  never overwrite existing files         -q  quiet mode (-qq => quieter)
#   -o  overwrite files WITHOUT prompting      -a  auto-convert any text files
# ...

# %%
# !unzip -o /home/dsc/Data/us_dot/traffic/T100_SEGMENT_ALL_CARRIER_2015.zip
# Out:
# Archive:  /home/dsc/Data/us_dot/traffic/T100_SEGMENT_ALL_CARRIER_2015.zip
#   inflating: 914310910_T_T100_SEGMENT_ALL_CARRIER_2015_All.csv
#   inflating: 914310910_T_T100_SEGMENT_ALL_CARRIER_ReadMe.csv
#   inflating: 914310910_T_T100_SEGMENT_ALL_CARRIER_Terms.csv

# %%
# !pwd
# Out:
# /home/dsc/Repositories/master-data-science-nacho/trabajos_jupiter/ejercicio_clase_Phyton

# %%
filename = '914310910_T_T100_SEGMENT_ALL_CARRIER_2015_All.csv'
df = pd.read_csv(filename)
df.sample(4)
# Out:
#         DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED    PAYLOAD   SEATS  \
# 35026                    0.0                   1.0    40170.0   160.0
# 77528                    5.0                   3.0   118839.0   450.0
# 57046                    1.0                   1.0    40400.0   150.0
# 142290                 108.0                 107.0  2407500.0  8132.0
#
#         PASSENGERS  FREIGHT   MAIL  DISTANCE  RAMP_TO_RAMP  AIR_TIME  \
# 35026        150.0    551.0    0.0     228.0          53.0      38.0
# 77528        348.0      5.0  963.0    1747.0         775.0     711.0
# 57046        131.0   3520.0    0.0      47.0          46.0      13.0
# 142290      7154.0   1066.0    0.0     511.0       10847.0    7730.0
#
#            ...      AIRCRAFT_GROUP  AIRCRAFT_TYPE AIRCRAFT_CONFIG  YEAR  \
# 35026      ...                   6            614               1  2015
# 77528      ...                   6            694               1  2015
# ...

# %% [markdown]
# # Saving to Excel

# %%
df.head(1000).to_excel('excel_out2.xls')

# %%
df.head(1000).to_excel('excel_out.xls')

# %%
# !ls
# Out:
# 01-numpy_pandas_introduction_blank.ipynb
# 02-loading_and_saving_data_blank.ipynb
# 03-merge_concatenate_transform_blank.ipynb
# 04-group_by_blank.ipynb
# 05-visualization_introduction_blank.ipynb
# 06-intro_to_pandas_practical_blank.ipynb
# 07-ejercicios_de_repaso_de_pandas_blank.ipynb
# 07-ejercicios_de_repaso_de_pandas.ipynb
# 2017-12-15-notebook.ipynb
# 2017-12-16-notebook.ipynb
# 914310910_T_T100_SEGMENT_ALL_CARRIER_2015_All.csv
# 914310910_T_T100_SEGMENT_ALL_CARRIER_ReadMe.csv
# 914310910_T_T100_SEGMENT_ALL_CARRIER_Terms.csv
# D1-numpy_pandas_introduction2.html
# D1-numpy_pandas_introduction.ipynb
# D2-loading_and_saving_data_blank.ipynb
# example.db
# excel_out.xls
# sample.csv

# %% [markdown]
# # Saving to CSV

# %%
df.sample(10).to_csv('sample.csv')

# %%
df.sample(3).to_csv()
# Out:
# ',DEPARTURES_SCHEDULED,DEPARTURES_PERFORMED,PAYLOAD,SEATS,PASSENGERS,FREIGHT,MAIL,DISTANCE,RAMP_TO_RAMP,AIR_TIME,UNIQUE_CARRIER,AIRLINE_ID,UNIQUE_CARRIER_NAME,UNIQUE_CARRIER_ENTITY,REGION,CARRIER,CARRIER_NAME,CARRIER_GROUP,CARRIER_GROUP_NEW,ORIGIN_AIRPORT_ID,ORIGIN_AIRPORT_SEQ_ID,ORIGIN_CITY_MARKET_ID,ORIGIN,ORIGIN_CITY_NAME,ORIGIN_STATE_ABR,ORIGIN_STATE_FIPS,ORIGIN_STATE_NM,ORIGIN_COUNTRY,ORIGIN_COUNTRY_NAME,ORIGIN_WAC,DEST_AIRPORT_ID,DEST_AIRPORT_SEQ_ID,DEST_CITY_MARKET_ID,DEST,DEST_CITY_NAME,DEST_STATE_ABR,DEST_STATE_FIPS,DEST_STATE_NM,DEST_COUNTRY,DEST_COUNTRY_NAME,DEST_WAC,AIRCRAFT_GROUP,AIRCRAFT_TYPE,AIRCRAFT_CONFIG,YEAR,QUARTER,MONTH,DISTANCE_GROUP,CLASS,DATA_SOURCE,Unnamed: 50\n34949,0.0,11.0,328900.0,1209.0,824.0,787.0,0.0,610.0,1202.0,989.0,DL,19790.0,Delta Air Lines Inc.,01260,D,DL,Delta Air Lines Inc.,3,3.0,13244,1324402,33244,MEM,"Memphis, TN",TN,47.0,Tennessee,US,United States,54,11433,1143302,31295,DTW,"Detroit, MI",MI,26.0,Michigan,US,United States,43,6,608,1,2015,2,4
# ...

# %% [markdown]
# # To Sql Database

# %%
import sqlite3

conn = sqlite3.connect('example.db')

# %%
df.to_sql('traffic', conn, if_exists='replace')
# Out:
# /home/dsc/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:1362: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   chunksize=chunksize, dtype=dtype)

# %%
df2 = pd.read_sql_query('SELECT * FROM traffic where passengers > 10000', conn)
df2
# Out:
#        index  DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED     PAYLOAD    SEATS  \
# 0         37                   0.0                  61.0   5365411.0  18353.0
# 1         42                   0.0                  61.0   5365411.0  18353.0
# 2         56                   0.0                  28.0   3619370.0  14448.0
# 3         58                   0.0                  31.0   4054899.0  15996.0
# 4         59                   0.0                  27.0   3470887.0  13836.0
# 5         77                   0.0                  26.0   3360843.0  13416.0
# 6         80                   0.0                  31.0   4054899.0  15996.0
# 7         85                   0.0                  27.0   3479696.0  13880.0
# 8        158                   0.0                  51.0   2706103.0  17384.0
# 9        159                   0.0                  51.0   2751949.0  17384.0
# 10       181                   0.0                  62.0   9292527.0  20584.0
# ...

# %% [markdown]
# # To dictionary and to json

# %%
df.sample(5).to_dict()
# Out:
# {'AIRCRAFT_CONFIG': {67821: 1, 97533: 2, 127541: 1, 140030: 1, 140443: 1},
#  'AIRCRAFT_GROUP': {67821: 6, 97533: 6, 127541: 6, 140030: 6, 140443: 6},
#  'AIRCRAFT_TYPE': {67821: 617,
#   97533: 692,
#   127541: 675,
#   140030: 678,
#   140443: 655},
#  'AIRLINE_ID': {67821: 19930.0,
#   97533: 20107.0,
#   127541: 20366.0,
#   140030: 20409.0,
#   140443: 19805.0},
#  'AIR_TIME': {67821: 303.0,
#   97533: 1223.0,
#   127541: 5209.0,
#   140030: 7053.0,
#   140443: 12716.0},
#  'CARRIER': {67821: 'AS',
#   97533: 'FX',
#   127541: 'EV',
#   140030: 'B6',
#   140443: 'AA'},
#  'CARRIER_GROUP': {67821: 3, 97533: 3, 127541: 3, 140030: 3, 140443: 3},
#  'CARRIER_GROUP_NEW': {67821: 3.0,
#   97533: 3.0,
#   127541: 3.0,
#   140030: 3.0,
#   140443: 3.0},
#  'CARRIER_NAME': {67821: 'Alaska Airlines Inc.',
#   97533: 'Federal Express Corporation',
#   127541: 'ExpressJet Airlines Inc.',
#   140030: 'JetBlue Airways',
#   140443: 'American Airlines Inc.'},
# ...

# %%
df.sample(5).to_json()
# Out:
# '{"DEPARTURES_SCHEDULED":{"18725":0.0,"100471":20.0,"124633":43.0,"26827":0.0,"46188":0.0},"DEPARTURES_PERFORMED":{"18725":1.0,"100471":20.0,"124633":39.0,"26827":1.0,"46188":2.0},"PAYLOAD":{"18725":89270.0,"100471":2148387.0,"124633":744588.0,"26827":6500.0,"46188":69200.0},"SEATS":{"18725":266.0,"100471":0.0,"124633":2691.0,"26827":30.0,"46188":286.0},"PASSENGERS":{"18725":232.0,"100471":0.0,"124633":1492.0,"26827":13.0,"46188":212.0},"FREIGHT":{"18725":670.0,"100471":1170731.0,"124633":0.0,"26827":0.0,"46188":256.0},"MAIL":{"18725":332.0,"100471":82310.0,"124633":0.0,"26827":0.0,"46188":0.0},"DISTANCE":{"18725":3166.0,"100471":1834.0,"124633":660.0,"26827":160.0,"46188":152.0},"RAMP_TO_RAMP":{"18725":375.0,"100471":4537.0,"124633":5034.0,"26827":48.0,"46188":141.0},"AIR_TIME":{"18725":351.0,"100471":4208.0,"124633":3579.0,"26827":36.0,"46188":116.0},"UNIQUE_CARRIER":{"18725":"UA","100471":"5X","124633":"S5","26827":"ZK","46188":"WN"},"AIRLINE_ID":{"18725":19977.0,"100471":19917.0,
# ...

# %% [markdown]
# # Reading Excel

# %%
accidentes_2009 = pd.read_excel('/home/dsc/Downloads/01_ ACCIDENTES POR TIPO EN  DISTRITOS.xls',skiprows=7,skipfooter=1,parse_cols='A:K')
accidentes_2009
# Out:
#                 DISTRITO_ACCIDENTE  COLISIÓN DOBLE                            \
# 0   ARGANZUELA                                                           389
# 1   BARAJAS                                                               89
# 2   CARABANCHEL                                                          375
# 3   CENTRO                                                               514
# 4   CHAMARTIN                                                            494
# 5   CHAMBERI                                                             414
# 6   CIUDAD LINEAL                                                        398
# 7   FUENCARRAL-EL PARDO                                                  321
# 8   HORTALEZA                                                            215
# 9   LATINA                                                               298
# 10  MONCLOA-ARAVACA                                                      340
# ...

# %%
accidentes_2010 = pd.read_excel('/home/dsc/Downloads/01_ ACCIDENTES POR TIPO EN  DISTRITOS.xls',skiprows=7,skipfooter=1,parse_cols='A:K',sheetname='2010')
accidentes_2010
# Out:
#                 DISTRITO_ACCIDENTE  COLISIÓN DOBLE                            \
# 0   ARGANZUELA                                                           403
# 1   BARAJAS                                                               62
# 2   CARABANCHEL                                                          357
# 3   CENTRO                                                               546
# 4   CHAMARTIN                                                            460
# 5   CHAMBERI                                                             361
# 6   CIUDAD LINEAL                                                        404
# 7   FUENCARRAL-EL PARDO                                                  294
# 8   HORTALEZA                                                            183
# 9   LATINA                                                               273
# 10  MONCLOA-ARAVACA                                                      350
# ...

# %%
accidentes_2009 = pd.read_excel('/home/dsc/Downloads/01_ ACCIDENTES POR TIPO EN  DISTRITOS.xls',
              skiprows=7,skipfooter=1,parse_cols='A:K',sheetname='2009')
accidentes_2009['YEAR']= '2009'

accidentes_2010 = pd.read_excel('/home/dsc/Downloads/01_ ACCIDENTES POR TIPO EN  DISTRITOS.xls',
              skiprows=7,skipfooter=1,parse_cols='A:K',sheetname='2010')
accidentes_2010['YEAR']= '2010'

accidentes_2011 = pd.read_excel('/home/dsc/Downloads/01_ ACCIDENTES POR TIPO EN  DISTRITOS.xls',
              skiprows=7,skipfooter=1,parse_cols='A:K',sheetname='2011')
accidentes_2011['YEAR']= '2011'

accidentes_totales = pd.concat([accidentes_2009, accidentes_2010, accidentes_2011], ignore_index=True)
accidentes_totales.sort_values(by=['DISTRITO_ACCIDENTE'])
#accidentes_totales[['DISTRITO_ACCIDENTE', 'YEAR', ]]
# Out:
#                 DISTRITO_ACCIDENTE  COLISIÓN DOBLE                            \
# 0   ARGANZUELA                                                           389
# 21  ARGANZUELA                                                           403
# 42  ARGANZUELA                                                           373
# 1   BARAJAS                                                               89
# 22  BARAJAS                                                               62
# 43  BARAJAS                                                               78
# 2   CARABANCHEL                                                          375
# 23  CARABANCHEL                                                          357
# 44  CARABANCHEL                                                          381
# 3   CENTRO                                                               514
# 24  CENTRO                                                               546
# ...

# %%
periodo = [2009,2010,2011,2012,2013,2014,2015]

pd

for i in periodo


accidentes_2009 = pd.read_excel('/home/dsc/Downloads/01_ ACCIDENTES POR TIPO EN  DISTRITOS.xls',
              skiprows=7,skipfooter=1,parse_cols='A:K',sheetname='2009')
accidentes_2009['YEAR']= '2009'

accidentes_2010 = pd.read_excel('/home/dsc/Downloads/01_ ACCIDENTES POR TIPO EN  DISTRITOS.xls',
              skiprows=7,skipfooter=1,parse_cols='A:K',sheetname='2010')
accidentes_2010['YEAR']= '2010'

accidentes_2011 = pd.read_excel('/home/dsc/Downloads/01_ ACCIDENTES POR TIPO EN  DISTRITOS.xls',
              skiprows=7,skipfooter=1,parse_cols='A:K',sheetname='2011')
accidentes_2011['YEAR']= '2011'

accidentes_totales = pd.concat([accidentes_2009, accidentes_2010, accidentes_2011], ignore_index=True)
accidentes_totales.sort_values(by=['DISTRITO_ACCIDENTE'])
# Out:
#   File "<ipython-input-17-b0ffa82f08aa>", line 5
#     for i in periodo
#                     ^
# SyntaxError: invalid syntax

# %%
sheets= pd.read_excel('/home/dsc/Downloads/01_ ACCIDENTES POR TIPO EN  DISTRITOS.xls',
              skiprows=7,skipfooter=1,parse_cols='A:K',sheetname=None)
sheets.keys()
result = []
for name in  sheets.keys():
    year = int(name)
    skiprows = 4 if year==2013 else 7
    this_sheet = pd.read_excel('/home/dsc/Downloads/01_ ACCIDENTES POR TIPO EN  DISTRITOS.xls',
              skiprows=skiprows,skipfooter=1,parse_cols='A:K',sheetname=name)
   
    this_sheet['YEAR']= year
    result.append(this_sheet)
    
whole_df = pd.concat(result)
whole_df.sample(4)

# %%
type(accidentes_2009)

# %% [markdown]
# #### Exercise
#
# Consolidate the excel into one DataFrame: you will need to create a 'YEAR' column. Think how you can iterate through all the DataFrames. Think also where you can take the value of 'YEAR' from.

# %% [markdown]
# # Reading mysql database
